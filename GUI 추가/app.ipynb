# %%
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QVBoxLayout, QLineEdit, QPushButton, QLabel
import requests
# Example usage:
weather_api_key = 'AIzaSyCpN60rYlKTr6l_y1IcEhZu2pvyV_oF4dI'

import requests
import json
# 발급받은 API 키를 입력합니다.
google_api_key = "UhIXqz3BxyzUBIOobK+yC+lbhlKx4lOWT5glOai8uSuRyW/ea2D6OBF7zp5WnyjTYcXyrzk+PXV2KtNrChOzOQ=="

# 기상청 날씨 데이터를 요청할 URL을 구성합니다.
# 이 URL은 예시일 뿐, 실제 URL은 공공데이터 포털에서 제공하는 API 문서를 참고하세요.
url = "http://apis.data.go.kr/1360000/VilageFcstInfoService_2.0/getVilageFcst"




class MyApp(QWidget):
    def __init__(self):
        super().__init__()
        self.initUI()

    def initUI(self):
        # 레이아웃 설정
        self.layout = QVBoxLayout()

        # 입력창 추가
        self.line_edit = QLineEdit(self)
        self.layout.addWidget(self.line_edit)

        # 버튼 추가
        self.button = QPushButton('클릭하세요', self)
        self.layout.addWidget(self.button)

        # 라벨 추가
        self.label = QLabel('', self)
        self.layout.addWidget(self.label)

        # 버튼 클릭 시 실행될 함수 연결
        self.button.clicked.connect(self.on_click)

        # 레이아웃 설정
        self.setLayout(self.layout)

        # 윈도우 설정
        self.setWindowTitle('PyQt5 입력창 예제')
        self.setGeometry(300, 300, 300, 200)
        self.show()

    def get_weather(self,latitude,longitude):  

        data = []
        params = {
            'serviceKey': weather_api_key,
            'numOfRows': '10',
            'pageNo': '1',
            'dataType': 'JSON',
            'base_date': '20240611',  # 기준 날짜 (YYYYMMDD)
            'base_time': '0500',      # 기준 시간 (HHMM)
            'nx': latitude,               # 위도
            'ny': longitude               # 경도
        }
        
        response = requests.get(url, params=params)
        
        if response.status_code == 200:
            data = response.json()
            if data != None:
                items = data['response']['body']['items']['item']
            
                # 데이터를 출력합니다.
                for item in items:
                    return item['fcstDate']
                    #data.append(f"예보일자: {item['fcstDate']}, 예보시간: {item['fcstTime']}, 예보값: {item['fcstValue']}, 카테고리: {item['category']}")
            else:
                return f"Error: {response.status_code}"
        
        else:
            return f"Error: {response.status_code}"

        return data
        
    def on_click(self):
        # 입력된 텍스트 가져오기
        input_text = self.line_edit.text()


        address = '서울특별시 종로구 종로1가'
        latitude, longitude = self.get_lat_lng(address, google_api_key)


        latitude= float(latitude)
        longitude = float(longitude)

        latitude= int(latitude)
        longitude = int(longitude)
        
        latitude= string(latitude)
        longitude = string(longitude)
        
        self.label.setText(f"Latitude(위도): {latitude}, Longitude(경도): {longitude}")
        data = self.get_weather(latitude, longitude)
        
        # 라벨에 텍스트 설정
        
        self.label.setText(f"data: {data}")
        
    def get_lat_lng(self,address, google_api_key):
        base_url = 'https://maps.googleapis.com/maps/api/geocode/json'
        params = {
            'address': address,
            'key': google_api_key
        }
        response = requests.get(base_url, params=params)
        
        if response.status_code == 200:
            data = response.json()
            if data['status'] == 'OK':
                geometry = data['results'][0]['geometry']['location']
                return geometry['lat'], geometry['lng']
            else:
                raise Exception(f"Geocoding API error: {data['status']}")
        else:
            raise Exception(f"Request error: {response.status_code}")


if __name__ == '__main__':
    app = QApplication(sys.argv)
    ex = MyApp()
    sys.exit(app.exec_())
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 90, in MyApp.on_click(self)
#      86 input_text = self.line_edit.text()
#      89 address = '서울특별시 종로구 종로1가'
# ---> 90 latitude, longitude = self.get_lat_lng(address, google_api_key)
#      93 latitude= float(latitude)
#      94 longitude = float(longitude)
#
# Cell In[1], line 123, in MyApp.get_lat_lng(self, address, google_api_key)
#     121         return geometry['lat'], geometry['lng']
#     122     else:
# --> 123         raise Exception(f"Geocoding API error: {data['status']}")
#     124 else:
#     125     raise Exception(f"Request error: {response.status_code}")
#
# Exception: Geocoding API error: REQUEST_DENIED
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# ...
