# %%
# %pip install langchain
# Out:
# Requirement already satisfied: langchain in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (0.2.1)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain) (3.9.5)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.0 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain) (0.2.3)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain) (0.2.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain) (0.1.67)
# Requirement already satisfied: numpy<2,>=1 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain) (2.7.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-core<0.3.0,>=0.2.0->langchain) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-core<0.3.0,>=0.2.0->langchain) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.3 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from pydantic<3,>=1->langchain) (2.18.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from pydantic<3,>=1->langchain) (4.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from requests<3,>=2->langchain) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from requests<3,>=2->langchain) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain) (2.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install langchain-core
# Out:
# Requirement already satisfied: langchain-core in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (0.2.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-core) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.65 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-core) (0.1.67)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-core) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-core) (2.7.2)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-core) (8.3.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langsmith<0.2.0,>=0.1.65->langchain-core) (3.10.3)
# Requirement already satisfied: requests<3,>=2 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langsmith<0.2.0,>=0.1.65->langchain-core) (2.32.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from pydantic<3,>=1->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.3 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from pydantic<3,>=1->langchain-core) (2.18.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from pydantic<3,>=1->langchain-core) (4.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.65->langchain-core) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.65->langchain-core) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.65->langchain-core) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.65->langchain-core) (2024.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install langchain-openai
# Out:
# Collecting langchain-openai
#   Using cached langchain_openai-0.1.8-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: langchain-core<0.3,>=0.2.2 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-openai) (0.2.3)
# Collecting openai<2.0.0,>=1.26.0 (from langchain-openai)
#   Using cached openai-1.30.5-py3-none-any.whl.metadata (21 kB)
# Collecting tiktoken<1,>=0.7 (from langchain-openai)
#   Using cached tiktoken-0.7.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain-openai) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.65 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain-openai) (0.1.67)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain-openai) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain-openai) (2.7.2)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain-openai) (8.3.0)
# Collecting anyio<5,>=3.5.0 (from openai<2.0.0,>=1.26.0->langchain-openai)
#   Using cached anyio-4.4.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting distro<2,>=1.7.0 (from openai<2.0.0,>=1.26.0->langchain-openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai<2.0.0,>=1.26.0->langchain-openai)
#   Using cached httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting sniffio (from openai<2.0.0,>=1.26.0->langchain-openai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai<2.0.0,>=1.26.0->langchain-openai)
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from openai<2.0.0,>=1.26.0->langchain-openai) (4.12.1)
# Collecting regex>=2022.1.18 (from tiktoken<1,>=0.7->langchain-openai)
#   Using cached regex-2024.5.15-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: requests>=2.26.0 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.26.0->langchain-openai) (3.7)
# Requirement already satisfied: certifi in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.26.0->langchain-openai) (2024.6.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai<2.0.0,>=1.26.0->langchain-openai)
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.26.0->langchain-openai)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.2.2->langchain-openai) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langsmith<0.2.0,>=0.1.65->langchain-core<0.3,>=0.2.2->langchain-openai) (3.10.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.2.2->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.3 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.2.2->langchain-openai) (2.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.2.1)
# Requirement already satisfied: colorama in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.26.0->langchain-openai) (0.4.6)
# Using cached langchain_openai-0.1.8-py3-none-any.whl (38 kB)
# Using cached openai-1.30.5-py3-none-any.whl (320 kB)
# Using cached tiktoken-0.7.0-cp312-cp312-win_amd64.whl (799 kB)
# Using cached anyio-4.4.0-py3-none-any.whl (86 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Using cached regex-2024.5.15-cp312-cp312-win_amd64.whl (268 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: tqdm, sniffio, regex, h11, distro, tiktoken, httpcore, anyio, httpx, openai, langchain-openai
# Successfully installed anyio-4.4.0 distro-1.9.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 langchain-openai-0.1.8 openai-1.30.5 regex-2024.5.15 sniffio-1.3.1 tiktoken-0.7.0 tqdm-4.66.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install langchain-community
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.2.1-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-community) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-community) (3.9.5)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.6-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: langchain<0.3.0,>=0.2.0 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-community) (0.2.1)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.0 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-community) (0.2.3)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-community) (0.1.67)
# Requirement already satisfied: numpy<2,>=1 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-community) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.4)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.21.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain<0.3.0,>=0.2.0->langchain-community) (0.2.0)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain<0.3.0,>=0.2.0->langchain-community) (2.7.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-core<0.3.0,>=0.2.0->langchain-community) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langchain-core<0.3.0,>=0.2.0->langchain-community) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (3.10.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from requests<3,>=2->langchain-community) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from requests<3,>=2->langchain-community) (2024.6.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (4.12.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain-community) (2.4)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.3 in c:\users\82106\desktop\sss\sss_langchange_study\env\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain-community) (2.18.3)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain_community-0.2.1-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.1 MB 14.5 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 34.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 19.5 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.6-py3-none-any.whl (28 kB)
# Downloading marshmallow-3.21.2-py3-none-any.whl (49 kB)
#    ---------------------------------------- 0.0/49.3 kB ? eta -:--:--
#    ---------------------------------------- 49.3/49.3 kB 2.6 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: mypy-extensions, marshmallow, typing-inspect, dataclasses-json, langchain-community
# Successfully installed dataclasses-json-0.6.6 langchain-community-0.2.1 marshmallow-3.21.2 mypy-extensions-1.0.0 typing-inspect-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip list
# Out:
# Package                  Version
# ------------------------ -----------
# aiohttp                  3.9.5
# aiosignal                1.3.1
# annotated-types          0.7.0
# anyio                    4.4.0
# asttokens                2.4.1
# attrs                    23.2.0
# certifi                  2024.6.2
# charset-normalizer       3.3.2
# colorama                 0.4.6
# comm                     0.2.2
# dataclasses-json         0.6.6
# debugpy                  1.8.1
# decorator                5.1.1
# distro                   1.9.0
# executing                2.0.1
# frozenlist               1.4.1
# greenlet                 3.0.3
# h11                      0.14.0
# httpcore                 1.0.5
# httpx                    0.27.0
# idna                     3.7
# ipykernel                6.29.4
# ipython                  8.25.0
# jedi                     0.19.1
# jsonpatch                1.33
# jsonpointer              2.4
# jupyter_client           8.6.2
# jupyter_core             5.7.2
# langchain                0.2.1
# langchain-community      0.2.1
# langchain-core           0.2.3
# langchain-openai         0.1.8
# langchain-text-splitters 0.2.0
# langsmith                0.1.67
# marshmallow              3.21.2
# matplotlib-inline        0.1.7
# multidict                6.0.5
# mypy-extensions          1.0.0
# nest-asyncio             1.6.0
# numpy                    1.26.4
# openai                   1.30.5
# orjson                   3.10.3
# packaging                23.2
# parso                    0.8.4
# pip                      24.0
# platformdirs             4.2.2
# prompt_toolkit           3.0.45
# psutil                   5.9.8
# pure-eval                0.2.2
# pydantic                 2.7.2
# pydantic_core            2.18.3
# Pygments                 2.18.0
# python-dateutil          2.9.0.post0
# pywin32                  306
# PyYAML                   6.0.1
# pyzmq                    26.0.3
# regex                    2024.5.15
# requests                 2.32.3
# six                      1.16.0
# sniffio                  1.3.1
# SQLAlchemy               2.0.30
# stack-data               0.6.3
# tenacity                 8.3.0
# tiktoken                 0.7.0
# tornado                  6.4
# tqdm                     4.66.4
# traitlets                5.14.3
# typing_extensions        4.12.1
# typing-inspect           0.9.0
# urllib3                  2.2.1
# wcwidth                  0.2.13
# yarl                     1.9.4
# Note: you may need to restart the kernel to use updated packages.
