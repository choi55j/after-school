# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False
data = pd.read_csv("장학1.csv", encoding='cp949',low_memory=False)
tuition = pd.read_csv("평균 등록금.csv", encoding="cp949", low_memory = False)
incoming  = pd.read_csv("01 2014-2023 대학별 학과별 모집인원.csv",encoding="cp949", low_memory = False)
Graduate = pd.read_csv("02 2014-2023년 대학별 학과별 졸업자.csv",encoding="cp949", low_memory = False)

# %%
data[data['학교명']=='가천대학교']
# Out:
#      학교명 설립별 지역별  교외장학금 소계(원)     교외장학금 국가  교외장학금 지방자치단체  교외장학금 사설및기타  \
# 2  가천대학교  사립  경기  40024949259  38565866879      97550440   1361531940
#
#    교내장학금 소계(원)  교내장학금 성적우수장학금  교내장학금 저소득층장학금  교내장학금 근로장학금  교내장학금 재난장학금  \
# 2  27726101831     6279840000     7994354780   1445094011      5000000
#
#    교내장학금 교직원장학금  교내장학금 기타장학금        총계(원)  Unnamed: 15
# 2     159614000  11842199040  67751051090          NaN

# %%
tuition[tuition["대학명"]=="가천대학교"]
# Out:
#    학제별 설립별    대학명 지역별  입학정원 합(명)  평균입학금(원)  평균등록금(원)
# 48  대학  사립  가천대학교  경기      16164         0   8330044

# %%
가천대입학명 = 가천대입학["모집인원"]
가천대입학명
# Out:
# 4948      50
# 4949     100
# 4950      80
# 4951      60
# 4952      55
#         ...
# 87064     30
# 87065     40
# 87066     40
# 87067     40
# 87068     20
# Name: 모집인원, Length: 570, dtype: int64

# %%
가천대입학=incoming[incoming["학교명"]=="가천대학교"]
한국어문학과 = 가천대입학[가천대입학["학과명"]=="한국어문학과"]
한국어문학과
# Out:
#        조사회차   학제    학교명        본분교   대계열    중계열     소계열     학과명  모집인원
# 4948   2014  대학교  가천대학교         본교  인문계열  언어ㆍ문학  국어ㆍ국문학  한국어문학과    50
# 14467  2015  대학교  가천대학교         본교  인문계열  언어ㆍ문학  국어ㆍ국문학  한국어문학과    48
# 23806  2016  대학교  가천대학교         본교  인문계열  언어ㆍ문학  국어ㆍ국문학  한국어문학과    50
# 32986  2017  대학교  가천대학교         본교  인문계열  언어ㆍ문학  국어ㆍ국문학  한국어문학과    50
# 41978  2018  대학교  가천대학교         본교  인문계열  언어ㆍ문학  국어ㆍ국문학  한국어문학과    50
# 50874  2019  대학교  가천대학교         본교  인문계열  언어ㆍ문학  국어ㆍ국문학  한국어문학과    50
# 59823  2020  대학교  가천대학교         본교  인문계열  언어ㆍ문학  국어ㆍ국문학  한국어문학과    50
# 68844  2021  대학교  가천대학교         본교  인문계열  언어ㆍ문학  국어ㆍ국문학  한국어문학과    50
# 77930  2022  대학교  가천대학교         본교  인문계열  언어ㆍ문학  국어ㆍ국문학  한국어문학과    50
# 87010  2023  대학교  가천대학교  본교(제1캠퍼스)  인문계열  언어ㆍ문학  국어ㆍ국문학  한국어문학과    50

# %%
가천대입학[가천대입학["조사회차"]=="2014"]
# Out:
# Empty DataFrame
# Columns: [조사회차, 학제, 학교명, 본분교, 대계열, 중계열, 소계열, 학과명, 모집인원]
# Index: []

# %%
sum(가천대입학명)
# Out:
# 38753

# %%
가천대졸업=Graduate[Graduate["학교명"]=="가천대학교"]
가천대졸업[가천대졸업["학과명"]=="한국어문학과"]
# Out:
#         조사회차   학제    학교명        본분교   대계열    중계열     소계열     학과명  졸업자
# 43156   2017  대학교  가천대학교         본교  인문계열  언어ㆍ문학  국어ㆍ국문학  한국어문학과   55
# 55689   2018  대학교  가천대학교         본교  인문계열  언어ㆍ문학  국어ㆍ국문학  한국어문학과   78
# 68207   2019  대학교  가천대학교         본교  인문계열  언어ㆍ문학  국어ㆍ국문학  한국어문학과   48
# 80662   2020  대학교  가천대학교         본교  인문계열  언어ㆍ문학  국어ㆍ국문학  한국어문학과   55
# 93158   2021  대학교  가천대학교         본교  인문계열  언어ㆍ문학  국어ㆍ국문학  한국어문학과   67
# 106049  2022  대학교  가천대학교         본교  인문계열  언어ㆍ문학  국어ㆍ국문학  한국어문학과   76
# 118963  2023  대학교  가천대학교  본교(제1캠퍼스)  인문계열  언어ㆍ문학  국어ㆍ국문학  한국어문학과   63
