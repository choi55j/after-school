# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Apr 24 16:57:11 2024

@author: kimru

교육 공공데이터를 활용한 창의적 아이디어 기획

"""

import pandas as pd
import numpy as np
import matplotlib as mpl           # 그래프를 그리는 패키지
import matplotlib.pyplot as plt    # 그래프를 그리는 패키지

# Windows 한글 폰트 설정
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)


# CSV 파일 읽기abs
df = pd.read_csv('2023.csv')




# 특정 칼럼의 특정 정보가 일치하는 행을 선택
target_column = '지역'  # 예를 들어, 성(Last Name)을 기준으로 선택하려면 이 값을 변경
target_value = '경기도 성남시 중원구'     # 선택하고 싶은 정보의 값
selected_rows = df[df[target_column] == target_value]

# 선택된 행 출력
print("경기도 성남시 중원구")
print(selected_rows['학교명'])



# 인덱스를 기준으로 'Column1'과 'Column2' 선택
index_column = '학교명'
column1 = '전입학생수(계)'
column2 = '전출학생수(계)'

# 그래프 그리기
plt.plot(selected_rows[index_column], selected_rows[column1], label=column1)
plt.plot(selected_rows[index_column], selected_rows[column2], label=column2)

# 그래프 타이틀과 라벨 설정
plt.title('Line Plot of Column1 and Column2')
plt.xlabel('Index')
plt.ylabel('Values')

# 범례 추가
plt.legend()


# 그래프 보이기
plt.show()





# 그래프 그리기
plt.bar(selected_rows[index_column], selected_rows[column1], color='red', label=column1, alpha=0.7)
plt.bar(selected_rows[index_column], selected_rows[column2], color='blue', label=column2, alpha=0.7)

# 그래프 타이틀과 라벨 설정
plt.title('Bar Plot of Column1 and Column2')
plt.xlabel('Index')
plt.ylabel('Values')

# 범례 추가
plt.legend()

# 그래프 보이기
plt.show()



#두개 막대로
#selected_rows[[column1, column2]].plot.bar()




data_sum = df['전체학생수(계)'].groupby(df['시도교육청'])


data_sum = data_sum.sum()


for data in data_sum:
    print(data)

data_sum = data_sum.sort_values()

index = data_sum.index
values = data_sum.values

print(index)
plt.bar(index, values, color='skyblue')

# x축 눈금 라벨 회전
plt.xticks(rotation=45)

# 그래프 보여주기
plt.show()

# -*- coding: utf-8 -*-
"""
Created on Fri Apr 26 14:19:07 2024

@author: kimru
"""


import pandas as pd
import numpy as np
import matplotlib as mpl           # 그래프를 그리는 패키지
import matplotlib.pyplot as plt    # 그래프를 그리는 패키지

# Windows 한글 폰트 설정
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)


# CSV 파일 읽기abs
df = pd.read_csv('2023.csv')



data_sum = df['전체학생수(계)'].groupby(df['시도교육청'])


data_sum = data_sum.sum()


for data in data_sum:
    print(data)

data_sum = data_sum.sort_values()

index = data_sum.index
values = data_sum.values

print(index)
plt.bar(index, values, color='skyblue')

# x축 눈금 라벨 회전
plt.xticks(rotation=45)

# 그래프 보여주기
plt.show()





data_sum = df['전입학생수(계)'].groupby(df['시도교육청']).sum()

for data in data_sum:
    print(data)

data_sum = data_sum.sort_values()

index = data_sum.index
values = data_sum.values

print(index)
plt.bar(index, values, color='skyblue')

# x축 눈금 라벨 회전
plt.xticks(rotation=45)

# 그래프 보여주기
plt.show()



data_sum = df['전출학생수(계)'].groupby(df['시도교육청']).sum()

for data in data_sum:
    print(data)

data_sum = data_sum.sort_values()

index = data_sum.index
values = data_sum.values

print(index)
plt.bar(index, values, color='skyblue')

# x축 눈금 라벨 회전
plt.xticks(rotation=45)

# 그래프 보여주기
plt.show()



#print(data_sum)

#print(type(data_sum))

#print(df.columns)

# 데이터프레임에서 필요한 열 선택
#x = df['학교명']
#y = df['전체학생수(계)']







#plt.bar(x, y, color='skyblue')

# x축 눈금 라벨 회전
#plt.xticks(rotation=45)

# 그래프 보여주기
#plt.show()
# Out:
# 경기도 성남시 중원구
# 1021    성남테크노과학고등학교
# 1022         성남고등학교
# 1023       성남여자고등학교
# 1028         성일고등학교
# 1029         동광고등학교
# 1030       성일정보고등학교
# 1056       숭신여자고등학교
# Name: 학교명, dtype: object
# 37747.0
# 342369.0
# 85173.0
# 63345.0
# 42253.0
# 60202.0
# 39572.0
# 70228.0
# 208804.0
# 11484.0
# 29784.0
# 72119.0
# 45310.0
# 48634.0
# 18523.0
# 56616.0
# 39492.0
# Index(['세종특별자치시교육청', '제주특별자치도교육청', '울산광역시교육청', '강원특별자치도교육청', '충청북도교육청',
#        '대전광역시교육청', '광주광역시교육청', '전라남도교육청', '전북특별자치도교육청', '충청남도교육청', '대구광역시교육청',
#        '경상북도교육청', '부산광역시교육청', '인천광역시교육청', '경상남도교육청', '서울특별시교육청', '경기도교육청'],
#       dtype='object', name='시도교육청')
# 37747.0
# 342369.0
# 85173.0
# 63345.0
# 42253.0
# 60202.0
# 39572.0
# 70228.0
# 208804.0
# 11484.0
# 29784.0
# 72119.0
# 45310.0
# 48634.0
# 18523.0
# 56616.0
# 39492.0
# Index(['세종특별자치시교육청', '제주특별자치도교육청', '울산광역시교육청', '강원특별자치도교육청', '충청북도교육청',
#        '대전광역시교육청', '광주광역시교육청', '전라남도교육청', '전북특별자치도교육청', '충청남도교육청', '대구광역시교육청',
# ...
